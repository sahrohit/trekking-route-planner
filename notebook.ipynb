# %% [markdown]
# <center> <h1> Trekking Route Planning for Nepali Mountain Trails based on Time, Distance and Difficulty </h1> </center>

# %% [markdown]
# ## Imports

# %%
import json
import csv
import os
import requests
import time

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Constants

# %%
RAW_GEOJSON_INPUT = [
    "dataset/raw/Barhabise to TshoRolpa.json",
    "dataset/raw/GairiHanumante to Simigaun.json",
    "dataset/raw/Gaurishankar Conservation Area.json",
    "dataset/raw/Jiri to Tsho Rolpa.json",
    "dataset/raw/Kapthang to Larcha.json",
]

# %% [markdown]
# ## Functions

# %% [markdown]
# ### To parse geojson into tabulated coordinates and location names

# %%
def geojson_to_table(geojson_files, output_file):
    """
    Convert multiple GeoJSON files to a tabulated list of names and coordinates.

    Args:
        geojson_files (list): List of paths to the input GeoJSON files.
        output_file (str): Path to the output CSV file.
    """
    # Initialize output table
    all_features = []

    # Process each GeoJSON file
    for geojson_file in geojson_files:
        try:
            # Read GeoJSON file
            with open(geojson_file, "r") as f:
                data = json.load(f)

            # Get filename without extension for reference
            base_filename = os.path.basename(geojson_file).split(".")[0]

            # Process features
            for feature in data.get("features", []):
                # Extract name or title (if available) from properties
                properties = feature.get("properties", {})
                name = properties.get(
                    "name", properties.get("title", f"Feature-{base_filename}")
                )

                # Extract geometry
                geometry = feature.get("geometry", {})
                geometry_type = geometry.get("type")
                coordinates = geometry.get("coordinates", [])

                # Handle different geometry types
                if geometry_type == "Point":
                    # Single point
                    all_features.append(
                        {
                            "name": name,
                            "type": "Point",
                            "longitude": coordinates[0],
                            "latitude": coordinates[1],
                            "source_file": geojson_file,
                        }
                    )
                elif geometry_type == "LineString":
                    # Line of points
                    for i, coord in enumerate(coordinates):
                        all_features.append(
                            {
                                "name": f"{name} (Point {i + 1})",
                                "type": "LineString",
                                "longitude": coord[0],
                                "latitude": coord[1],
                                "source_file": geojson_file,
                            }
                        )
                elif geometry_type == "Polygon":
                    # Polygon (using outer ring only)
                    for i, coord in enumerate(coordinates[0]):
                        all_features.append(
                            {
                                "name": f"{name} (Vertex {i + 1})",
                                "type": "Polygon",
                                "longitude": coord[0],
                                "latitude": coord[1],
                                "source_file": geojson_file,
                            }
                        )
                elif geometry_type == "MultiPoint":
                    # Multiple points
                    for i, coord in enumerate(coordinates):
                        all_features.append(
                            {
                                "name": f"{name} (Point {i + 1})",
                                "type": "MultiPoint",
                                "longitude": coord[0],
                                "latitude": coord[1],
                                "source_file": geojson_file,
                            }
                        )
                elif geometry_type == "MultiLineString":
                    # Multiple lines
                    for j, line in enumerate(coordinates):
                        for i, coord in enumerate(line):
                            all_features.append(
                                {
                                    "name": f"{name} (Line {j + 1}, Point {i + 1})",
                                    "type": "MultiLineString",
                                    "longitude": coord[0],
                                    "latitude": coord[1],
                                    "source_file": geojson_file,
                                }
                            )
                elif geometry_type == "MultiPolygon":
                    # Multiple polygons (using outer rings only)
                    for j, polygon in enumerate(coordinates):
                        for i, coord in enumerate(polygon[0]):
                            all_features.append(
                                {
                                    "name": f"{name} (Polygon {j + 1}, Vertex {i + 1})",
                                    "type": "MultiPolygon",
                                    "longitude": coord[0],
                                    "latitude": coord[1],
                                    "source_file": geojson_file,
                                }
                            )

            print(f"Processed {geojson_file}")

        except Exception as e:
            print(f"Error processing {geojson_file}: {e}")

    # Write to CSV
    with open(output_file, "w", newline="") as f:
        writer = csv.DictWriter(
            f, fieldnames=["name", "type", "longitude", "latitude", "source_file"]
        )
        writer.writeheader()
        writer.writerows(all_features)

    print(
        f"Converted {len(all_features)} coordinates from {len(geojson_files)} files to {output_file}"
    )
    return all_features

# %%
# Or use wildcard pattern:
# input_files = glob.glob("data/*.geojson")

# Convert all files and combine into one CSV
features = geojson_to_table(
    RAW_GEOJSON_INPUT, "dataset/processed/combined_locations.csv"
)

# You can now also work with the features in memory if needed
print(f"Total features extracted: {len(features)}")
# Out:
# Processed dataset/raw/Barhabise to TshoRolpa.json
# Processed dataset/raw/GairiHanumante to Simigaun.json
# Processed dataset/raw/Gaurishankar Conservation Area.json
# Processed dataset/raw/Jiri to Tsho Rolpa.json
# Processed dataset/raw/Kapthang to Larcha.json
# Converted 1107 coordinates from 5 files to dataset/processed/combined_locations.csv
# Total features extracted: 1107

# %% [markdown]
# ## OSM Data Fetching

# %%
def get_location_info(lat, lon):
    """
    Get location information from OpenStreetMap's Nominatim API using coordinates
    """
    # Nominatim API endpoint for reverse geocoding
    url = f"https://nominatim.openstreetmap.org/reverse?lat={lat}&lon={lon}&format=json"

    # Make sure to add a user agent as per Nominatim usage policy
    headers = {"User-Agent": "LocationLookupScript/1.0"}

    try:
        # Make the request to the API
        response = requests.get(url, headers=headers)

        # Check if the request was successful
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error: Received status code {response.status_code}")
            return None
    except Exception as e:
        print(f"Error making request: {e}")
        return None


def process_csv_file(csv_file_path, output_file_path):
    """
    Process a CSV file containing coordinates and fetch location information for each entry
    """
    results = []

    try:
        with open(csv_file_path, "r") as file:
            # Use CSV reader to parse the file
            csv_reader = csv.reader(file)

            # Skip the header row
            next(csv_reader)

            # Process each row
            for row in csv_reader:
                # Parse the data from the row
                name = row[0].strip('"')
                feature_type = row[1].strip()
                longitude = float(row[2].strip())
                latitude = float(row[3].strip("* "))
                source_file = row[4].strip("* ")

                print(f"Processing: {name}")

                # Get location information from OpenStreetMap
                location_info = get_location_info(latitude, longitude)

                print("Location Info", location_info)

                # Append results
                results.append(
                    {
                        "name": name,
                        "type": feature_type,
                        "longitude": longitude,
                        "latitude": latitude,
                        "source_file": source_file,
                        "location_info": location_info,
                    }
                )

                # Sleep to respect the usage policy (1 request per second is safe)
                time.sleep(1)

    except Exception as e:
        print(f"Error processing CSV file: {e}")

    # Save the results to a JSON file
    with open(output_file_path, "w") as outfile:
        json.dump(results, outfile, indent=2)

    print(f"Results saved to {output_file_path}")

# %%
process_csv_file(
    "dataset/processed/combined_locations.csv", "dataset/processed/location_info.json"
)
# Out:
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 1)
# Location Info {'place_id': 224443884, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 942708593, 'lat': '27.786988464550575', 'lon': '85.89968218340306', 'class': 'highway', 'type': 'trunk', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': 'Arniko Highway', 'display_name': 'Arniko Highway, Barhabise-04, Bāhrabīse, Barhabise, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'road': 'Arniko Highway', 'city_district': 'Barhabise-04', 'village': 'Bāhrabīse', 'municipality': 'Barhabise', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.7869645', '27.7917041', '85.8979360', '85.9000202']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 2)
# Location Info {'place_id': 226500031, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 341647092, 'lat': '27.79319256802568', 'lon': '85.9257196089937', 'class': 'highway', 'type': 'tertiary', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': 'Bahrabise - Karthali - Dolangsa Road', 'display_name': 'Bahrabise - Karthali - Dolangsa Road, Drumtali, Barhabise-02, Karthali, Barhabise, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'road': 'Bahrabise - Karthali - Dolangsa Road', 'hamlet': 'Drumtali', 'city_district': 'Barhabise-02', 'village': 'Karthali', 'municipality': 'Barhabise', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.7875653', '27.8147652', '85.9097004', '85.9937360']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 3)
# Location Info {'place_id': 226500031, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 341647092, 'lat': '27.795663960722315', 'lon': '85.9390969784248', 'class': 'highway', 'type': 'tertiary', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': 'Bahrabise - Karthali - Dolangsa Road', 'display_name': 'Bahrabise - Karthali - Dolangsa Road, Drumtali, Barhabise-02, Karthali, Barhabise, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'road': 'Bahrabise - Karthali - Dolangsa Road', 'hamlet': 'Drumtali', 'city_district': 'Barhabise-02', 'village': 'Karthali', 'municipality': 'Barhabise', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.7875653', '27.8147652', '85.9097004', '85.9937360']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 4)
# Location Info {'place_id': 225210668, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 941469165, 'lat': '27.790817641985566', 'lon': '85.94333633807582', 'class': 'highway', 'type': 'unclassified', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': '', 'display_name': 'Budepa, Barhabise-02, Karthali, Barhabise, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Budepa', 'city_district': 'Barhabise-02', 'village': 'Karthali', 'municipality': 'Barhabise', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.7837040', '27.7909463', '85.9428052', '85.9502475']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 5)
# Location Info {'place_id': 222621734, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 341647103, 'lat': '27.7830806', 'lon': '85.9451403', 'class': 'highway', 'type': 'tertiary', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': 'Bahrabise - Budepa Road', 'display_name': 'Bahrabise - Budepa Road, Budepa, Barhabise-02, Simle, Barhabise, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'road': 'Bahrabise - Budepa Road', 'hamlet': 'Budepa', 'city_district': 'Barhabise-02', 'village': 'Simle', 'municipality': 'Barhabise', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.7823371', '27.7866371', '85.9051922', '85.9467214']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 6)
# Location Info {'place_id': 224303414, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 340435707, 'lat': '27.78176608087646', 'lon': '85.96293581450017', 'class': 'highway', 'type': 'tertiary', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': 'Bahrabise - Budepa - Ghorthali Road', 'display_name': 'Bahrabise - Budepa - Ghorthali Road, Tripurasundari-01, Ghorthali, Tripurasundari, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'road': 'Bahrabise - Budepa - Ghorthali Road', 'city_district': 'Tripurasundari-01', 'village': 'Ghorthali', 'municipality': 'Tripurasundari', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.7812526', '27.7852624', '85.9467214', '85.9787399']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 7)
# Location Info {'place_id': 222521593, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 939352668, 'lat': '27.785881709999963', 'lon': '85.97925486999999', 'class': 'highway', 'type': 'unclassified', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': '', 'display_name': 'Tripurasundari-01, Ghorthali, Tripurasundari, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'city_district': 'Tripurasundari-01', 'village': 'Ghorthali', 'municipality': 'Tripurasundari', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.7846973', '27.7863149', '85.9786356', '85.9793294']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 8)
# Location Info {'place_id': 224181646, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 8758375125, 'lat': '27.7950276', 'lon': '85.9884118', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.1333833348592355, 'addresstype': 'hamlet', 'name': 'Chyanarsa', 'display_name': 'Chyanarsa, Barhabise-01, Barhabise, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Chyanarsa', 'city_district': 'Barhabise-01', 'municipality': 'Barhabise', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.7750276', '27.8150276', '85.9684118', '86.0084118']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 9)
# Location Info {'place_id': 222521657, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 328238043, 'lat': '27.8017459', 'lon': '85.9907309', 'class': 'highway', 'type': 'unclassified', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': '', 'display_name': 'Chyanarsa, Barhabise-01, Barhabise, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Chyanarsa', 'city_district': 'Barhabise-01', 'municipality': 'Barhabise', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.7860348', '27.8129429', '85.9790966', '85.9945006']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 10)
# Location Info {'place_id': 224019992, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 340435694, 'lat': '27.81790814895233', 'lon': '86.00199655666405', 'class': 'highway', 'type': 'unclassified', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': 'Bahrabise - Karthali - Dolangsa Road', 'display_name': 'Bahrabise - Karthali - Dolangsa Road, Dolansa, Barhabise-01, Barhabise, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'road': 'Bahrabise - Karthali - Dolangsa Road', 'hamlet': 'Dolansa', 'city_district': 'Barhabise-01', 'municipality': 'Barhabise', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8119510', '27.8249414', '85.9913758', '86.0050395']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 11)
# Location Info {'place_id': 223425418, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 340435703, 'lat': '27.8240638', 'lon': '86.0072456', 'class': 'highway', 'type': 'unclassified', 'place_rank': 26, 'importance': 0.05337333409628439, 'addresstype': 'road', 'name': '', 'display_name': 'Bigu-07, Bigu, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'city_district': 'Bigu-07', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8181411', '27.8266878', '86.0072456', '86.0111253']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 12)
# Location Info {'place_id': 222527083, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 340435709, 'lat': '27.83185319545625', 'lon': '86.01245002700848', 'class': 'highway', 'type': 'unclassified', 'place_rank': 26, 'importance': 0.05337333409628439, 'addresstype': 'road', 'name': '', 'display_name': 'Bigu-07, Bigu, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'city_district': 'Bigu-07', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8266878', '27.8325768', '86.0077395', '86.0187924']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 13)
# Location Info {'place_id': 224822203, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 341264891, 'lat': '27.8330462', 'lon': '86.0247079', 'class': 'highway', 'type': 'unclassified', 'place_rank': 26, 'importance': 0.05337333409628439, 'addresstype': 'road', 'name': '', 'display_name': 'Bigu-07, Bigu, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'city_district': 'Bigu-07', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8310238', '27.8332354', '86.0243580', '86.0321887']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 14)
# Location Info {'place_id': 224822203, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 341264891, 'lat': '27.83245', 'lon': '86.029838', 'class': 'highway', 'type': 'unclassified', 'place_rank': 26, 'importance': 0.05337333409628439, 'addresstype': 'road', 'name': '', 'display_name': 'Bigu-07, Bigu, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'city_district': 'Bigu-07', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8310238', '27.8332354', '86.0243580', '86.0321887']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 15)
# Location Info {'place_id': 224605967, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6743313, 'lat': '27.8402896', 'lon': '86.0528997345248', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.16004000076295108, 'addresstype': 'city_district', 'name': 'Bigu-07', 'display_name': 'Bigu-07, Bigu, दोलखा, बागमती प्रदेश, 45510, नेपाल', 'address': {'city_district': 'Bigu-07', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'postcode': '45510', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8088281', '27.8718814', '86.0023737', '86.0966023']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 16)
# Location Info {'place_id': 224390720, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 946091289, 'lat': '27.8373414', 'lon': '86.0509233', 'class': 'highway', 'type': 'tertiary', 'place_rank': 26, 'importance': 0.05337333409628439, 'addresstype': 'road', 'name': 'Bigu - Choitang - Gaglate Road', 'display_name': 'Bigu - Choitang - Gaglate Road, Bigu-07, Bigu, दोलखा, बागमती प्रदेश, 45510, नेपाल', 'address': {'road': 'Bigu - Choitang - Gaglate Road', 'city_district': 'Bigu-07', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'postcode': '45510', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8336910', '27.8377318', '86.0403343', '86.0513001']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 17)
# Location Info {'place_id': 224439871, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 340651368, 'lat': '27.838085868053554', 'lon': '86.06933420129278', 'class': 'highway', 'type': 'tertiary', 'place_rank': 26, 'importance': 0.05337333409628439, 'addresstype': 'road', 'name': 'Bigu - Choitang - Gaglate Road', 'display_name': 'Bigu - Choitang - Gaglate Road, Gyalwasin, Bigu-07, Bigu, दोलखा, बागमती प्रदेश, 45510, नेपाल', 'address': {'road': 'Bigu - Choitang - Gaglate Road', 'hamlet': 'Gyalwasin', 'city_district': 'Bigu-07', 'village': 'Bigu', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'postcode': '45510', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8367943', '27.8395317', '86.0531533', '86.0718074']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 18)
# Location Info {'place_id': 225974945, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1309206544, 'lat': '27.8353893', 'lon': '86.083321', 'class': 'highway', 'type': 'tertiary', 'place_rank': 26, 'importance': 0.05337333409628439, 'addresstype': 'road', 'name': 'Singati-Bigu Road', 'display_name': 'Singati-Bigu Road, Sangba Bazar, Bigu-07, Chapsing, Bigu, दोलखा, बागमती प्रदेश, 45510, नेपाल', 'address': {'road': 'Singati-Bigu Road', 'hamlet': 'Sangba Bazar', 'city_district': 'Bigu-07', 'village': 'Chapsing', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'postcode': '45510', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8255410', '27.8361873', '86.0747861', '86.0897215']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 19)
# Location Info {'place_id': 223783746, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1309206545, 'lat': '27.8344053', 'lon': '86.0884833', 'class': 'highway', 'type': 'tertiary', 'place_rank': 26, 'importance': 0.05337333409628439, 'addresstype': 'road', 'name': 'Singati-Bigu Road', 'display_name': 'Singati-Bigu Road, Nagara, Bigu-07, Alampu, Bigu, दोलखा, बागमती प्रदेश, 45510, नेपाल', 'address': {'road': 'Singati-Bigu Road', 'hamlet': 'Nagara', 'city_district': 'Bigu-07', 'village': 'Alampu', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'postcode': '45510', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8325719', '27.8387299', '86.0809454', '86.1023360']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 20)
# Location Info {'place_id': 223783746, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1309206545, 'lat': '27.83420764144062', 'lon': '86.09073134358593', 'class': 'highway', 'type': 'tertiary', 'place_rank': 26, 'importance': 0.05337333409628439, 'addresstype': 'road', 'name': 'Singati-Bigu Road', 'display_name': 'Singati-Bigu Road, Nagara, Bigu-07, Alampu, Bigu, दोलखा, बागमती प्रदेश, 45510, नेपाल', 'address': {'road': 'Singati-Bigu Road', 'hamlet': 'Nagara', 'city_district': 'Bigu-07', 'village': 'Alampu', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'postcode': '45510', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8325719', '27.8387299', '86.0809454', '86.1023360']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 21)
# Location Info {'place_id': 224866609, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1309206546, 'lat': '27.830993548369523', 'lon': '86.09516204098993', 'class': 'highway', 'type': 'tertiary', 'place_rank': 26, 'importance': 0.05337333409628439, 'addresstype': 'road', 'name': 'Singati-Bigu Road', 'display_name': 'Singati-Bigu Road, Pegu, Sangba Bazar, Bigu-07, Amanthali Bazar, Bigu, दोलखा, बागमती प्रदेश, 45510, नेपाल', 'address': {'road': 'Singati-Bigu Road', 'residential': 'Pegu', 'hamlet': 'Sangba Bazar', 'city_district': 'Bigu-07', 'village': 'Amanthali Bazar', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'postcode': '45510', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8248170', '27.8340926', '86.0941968', '86.0965706']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 22)
# Location Info {'place_id': 224866609, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1309206546, 'lat': '27.8263849', 'lon': '86.0946471', 'class': 'highway', 'type': 'tertiary', 'place_rank': 26, 'importance': 0.05337333409628439, 'addresstype': 'road', 'name': 'Singati-Bigu Road', 'display_name': 'Singati-Bigu Road, Pegu, Sangba Bazar, Bigu-07, Amanthali Bazar, Bigu, दोलखा, बागमती प्रदेश, 45510, नेपाल', 'address': {'road': 'Singati-Bigu Road', 'residential': 'Pegu', 'hamlet': 'Sangba Bazar', 'city_district': 'Bigu-07', 'village': 'Amanthali Bazar', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'postcode': '45510', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8248170', '27.8340926', '86.0941968', '86.0965706']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 23)
# Location Info {'place_id': 224300435, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 344458682, 'lat': '27.8270767', 'lon': '86.1015541', 'class': 'highway', 'type': 'tertiary', 'place_rank': 26, 'importance': 0.05337333409628439, 'addresstype': 'road', 'name': 'Chilankha-Syakhu-Alampu-Bigu Road', 'display_name': 'Chilankha-Syakhu-Alampu-Bigu Road, Bigu-05, Amanthali Bazar, Bigu, दोलखा, बागमती प्रदेश, 45510, नेपाल', 'address': {'road': 'Chilankha-Syakhu-Alampu-Bigu Road', 'city_district': 'Bigu-05', 'village': 'Amanthali Bazar', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'postcode': '45510', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8190298', '27.8310356', '86.1015514', '86.1082489']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 24)
# Location Info {'place_id': 224300435, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 344458682, 'lat': '27.821909', 'lon': '86.1036772', 'class': 'highway', 'type': 'tertiary', 'place_rank': 26, 'importance': 0.05337333409628439, 'addresstype': 'road', 'name': 'Chilankha-Syakhu-Alampu-Bigu Road', 'display_name': 'Chilankha-Syakhu-Alampu-Bigu Road, Bigu-05, Amanthali Bazar, Bigu, दोलखा, बागमती प्रदेश, 45510, नेपाल', 'address': {'road': 'Chilankha-Syakhu-Alampu-Bigu Road', 'city_district': 'Bigu-05', 'village': 'Amanthali Bazar', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'postcode': '45510', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8190298', '27.8310356', '86.1015514', '86.1082489']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 25)
# Location Info {'place_id': 224178770, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 344458680, 'lat': '27.8306655', 'lon': '86.1101882', 'class': 'highway', 'type': 'tertiary', 'place_rank': 26, 'importance': 0.05337333409628439, 'addresstype': 'road', 'name': 'Chilankha-Syakhu-Alampu-Bigu Road', 'display_name': 'Chilankha-Syakhu-Alampu-Bigu Road, Syakhu, Bigu-05, Alampu, Bigu, दोलखा, बागमती प्रदेश, 45510, नेपाल', 'address': {'road': 'Chilankha-Syakhu-Alampu-Bigu Road', 'hamlet': 'Syakhu', 'city_district': 'Bigu-05', 'village': 'Alampu', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'postcode': '45510', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8306418', '27.8415215', '86.1082489', '86.1166925']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 26)
# Location Info {'place_id': 225207720, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 8710473705, 'lat': '27.8179665', 'lon': '86.1276189', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.1333733340962844, 'addresstype': 'hamlet', 'name': 'Pheldar', 'display_name': 'Pheldar, Bigu-05, Chilankha, Bigu, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Pheldar', 'city_district': 'Bigu-05', 'village': 'Chilankha', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.7979665', '27.8379665', '86.1076189', '86.1476189']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 27)
# Location Info {'place_id': 225207720, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 8710473705, 'lat': '27.8179665', 'lon': '86.1276189', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.1333733340962844, 'addresstype': 'hamlet', 'name': 'Pheldar', 'display_name': 'Pheldar, Bigu-05, Chilankha, Bigu, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Pheldar', 'city_district': 'Bigu-05', 'village': 'Chilankha', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.7979665', '27.8379665', '86.1076189', '86.1476189']}
# Processing: Feature-Barhabise to TshoRolpa (Line 1, Point 28)
# Location Info {'place_id': 224178298, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5027958820, 'lat': '27.8257055', 'lon': '86.1259501', 'class': 'amenity', 'type': 'school', 'place_rank': 30, 'importance': 4.0000762951049326e-05, 'addresstype': 'amenity', 'name': 'Shree Janta Pra V', 'display_name': 'Shree Janta Pra V, Chilankha-Syakhu-Alampu-Bigu Road, Yarsa, Bigu-05, Chilankha, Bigu, दोलखा, बागमती प्रदेश, 45510, नेपाल', 'address': {'amenity': 'Shree Janta Pra V', 'road': 'Chilankha-Syakhu-Alampu-Bigu Road', 'hamlet': 'Yarsa', 'city_district': 'Bigu-05', 'village': 'Chilankha', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'postcode': '45510', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8256555', '27.8257555', '86.1259001', '86.1260001']}
# Processing: Feature-Barhabise to TshoRolpa (Line 2, Point 1)
# Location Info {'place_id': 225207629, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5045699845, 'lat': '27.8713774', 'lon': '86.2338938', 'class': 'amenity', 'type': 'school', 'place_rank': 30, 'importance': 5.000152590214416e-05, 'addresstype': 'amenity', 'name': 'Shri Choing Choling Gumba', 'display_name': 'Shri Choing Choling Gumba, NH28, Chetchet, Bigu-01, Lamabagar, Bigu, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'amenity': 'Shri Choing Choling Gumba', 'road': 'NH28', 'hamlet': 'Chetchet', 'city_district': 'Bigu-01', 'village': 'Lamabagar', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8713274', '27.8714274', '86.2338438', '86.2339438']}
# Processing: Feature-Barhabise to TshoRolpa (Line 2, Point 2)
# Location Info {'place_id': 224537125, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 539811080, 'lat': '27.872357100000002', 'lon': '86.23389925000001', 'class': 'amenity', 'type': 'restaurant', 'place_rank': 30, 'importance': 5.000152590214416e-05, 'addresstype': 'amenity', 'name': 'Guest House', 'display_name': 'Guest House, NH28, Chetchet, Bigu-01, Lamabagar, Bigu, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'amenity': 'Guest House', 'road': 'NH28', 'hamlet': 'Chetchet', 'city_district': 'Bigu-01', 'village': 'Lamabagar', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8723352', '27.8723790', '86.2338728', '86.2339257']}
# Processing: Feature-Barhabise to TshoRolpa (Line 3, Point 1)
# Location Info {'place_id': 224537125, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 539811080, 'lat': '27.872357100000002', 'lon': '86.23389925000001', 'class': 'amenity', 'type': 'restaurant', 'place_rank': 30, 'importance': 5.000152590214416e-05, 'addresstype': 'amenity', 'name': 'Guest House', 'display_name': 'Guest House, NH28, Chetchet, Bigu-01, Lamabagar, Bigu, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'amenity': 'Guest House', 'road': 'NH28', 'hamlet': 'Chetchet', 'city_district': 'Bigu-01', 'village': 'Lamabagar', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8723352', '27.8723790', '86.2338728', '86.2339257']}
# Processing: Feature-Barhabise to TshoRolpa (Line 3, Point 2)
# Location Info {'place_id': 224537125, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 539811080, 'lat': '27.872357100000002', 'lon': '86.23389925000001', 'class': 'amenity', 'type': 'restaurant', 'place_rank': 30, 'importance': 5.000152590214416e-05, 'addresstype': 'amenity', 'name': 'Guest House', 'display_name': 'Guest House, NH28, Chetchet, Bigu-01, Lamabagar, Bigu, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'amenity': 'Guest House', 'road': 'NH28', 'hamlet': 'Chetchet', 'city_district': 'Bigu-01', 'village': 'Lamabagar', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8723352', '27.8723790', '86.2338728', '86.2339257']}
# Processing: Feature-Barhabise to TshoRolpa (Line 4, Point 1)
# Location Info {'place_id': 224537125, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 539811080, 'lat': '27.872357100000002', 'lon': '86.23389925000001', 'class': 'amenity', 'type': 'restaurant', 'place_rank': 30, 'importance': 5.000152590214416e-05, 'addresstype': 'amenity', 'name': 'Guest House', 'display_name': 'Guest House, NH28, Chetchet, Bigu-01, Lamabagar, Bigu, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'amenity': 'Guest House', 'road': 'NH28', 'hamlet': 'Chetchet', 'city_district': 'Bigu-01', 'village': 'Lamabagar', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8723352', '27.8723790', '86.2338728', '86.2339257']}
# Processing: Feature-Barhabise to TshoRolpa (Line 4, Point 2)
# Location Info {'place_id': 224537125, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 539811080, 'lat': '27.872357100000002', 'lon': '86.23389925000001', 'class': 'amenity', 'type': 'restaurant', 'place_rank': 30, 'importance': 5.000152590214416e-05, 'addresstype': 'amenity', 'name': 'Guest House', 'display_name': 'Guest House, NH28, Chetchet, Bigu-01, Lamabagar, Bigu, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'amenity': 'Guest House', 'road': 'NH28', 'hamlet': 'Chetchet', 'city_district': 'Bigu-01', 'village': 'Lamabagar', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8723352', '27.8723790', '86.2338728', '86.2339257']}
# Processing: Feature-Barhabise to TshoRolpa (Line 4, Point 3)
# Location Info {'place_id': 224537125, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 539811080, 'lat': '27.872357100000002', 'lon': '86.23389925000001', 'class': 'amenity', 'type': 'restaurant', 'place_rank': 30, 'importance': 5.000152590214416e-05, 'addresstype': 'amenity', 'name': 'Guest House', 'display_name': 'Guest House, NH28, Chetchet, Bigu-01, Lamabagar, Bigu, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'amenity': 'Guest House', 'road': 'NH28', 'hamlet': 'Chetchet', 'city_district': 'Bigu-01', 'village': 'Lamabagar', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8723352', '27.8723790', '86.2338728', '86.2339257']}
# Processing: Feature-Barhabise to TshoRolpa (Line 5, Point 1)
# Location Info {'place_id': 224537125, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 539811080, 'lat': '27.872357100000002', 'lon': '86.23389925000001', 'class': 'amenity', 'type': 'restaurant', 'place_rank': 30, 'importance': 5.000152590214416e-05, 'addresstype': 'amenity', 'name': 'Guest House', 'display_name': 'Guest House, NH28, Chetchet, Bigu-01, Lamabagar, Bigu, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'amenity': 'Guest House', 'road': 'NH28', 'hamlet': 'Chetchet', 'city_district': 'Bigu-01', 'village': 'Lamabagar', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8723352', '27.8723790', '86.2338728', '86.2339257']}
# Processing: Feature-Barhabise to TshoRolpa (Line 5, Point 2)
# Location Info {'place_id': 225685511, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5223183087, 'lat': '27.8862405', 'lon': '86.2446445', 'class': 'place', 'type': 'isolated_dwelling', 'place_rank': 22, 'importance': 0.10671666819256884, 'addresstype': 'isolated_dwelling', 'name': 'Bamboo Bhatti', 'display_name': 'Bamboo Bhatti, Gaurishankar-09, Gaurishankar, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'isolated_dwelling': 'Bamboo Bhatti', 'city_district': 'Gaurishankar-09', 'municipality': 'Gaurishankar', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8861905', '27.8862905', '86.2445945', '86.2446945']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 1)
# Location Info {'place_id': 224537125, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 539811080, 'lat': '27.872357100000002', 'lon': '86.23389925000001', 'class': 'amenity', 'type': 'restaurant', 'place_rank': 30, 'importance': 5.000152590214416e-05, 'addresstype': 'amenity', 'name': 'Guest House', 'display_name': 'Guest House, NH28, Chetchet, Bigu-01, Lamabagar, Bigu, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'amenity': 'Guest House', 'road': 'NH28', 'hamlet': 'Chetchet', 'city_district': 'Bigu-01', 'village': 'Lamabagar', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8723352', '27.8723790', '86.2338728', '86.2339257']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 2)
# Location Info {'place_id': 225685511, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5223183087, 'lat': '27.8862405', 'lon': '86.2446445', 'class': 'place', 'type': 'isolated_dwelling', 'place_rank': 22, 'importance': 0.10671666819256884, 'addresstype': 'isolated_dwelling', 'name': 'Bamboo Bhatti', 'display_name': 'Bamboo Bhatti, Gaurishankar-09, Gaurishankar, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'isolated_dwelling': 'Bamboo Bhatti', 'city_district': 'Gaurishankar-09', 'municipality': 'Gaurishankar', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8861905', '27.8862905', '86.2445945', '86.2446945']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 3)
# Location Info {'place_id': 224015837, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 11342719569, 'lat': '27.8878572', 'lon': '86.2583097', 'class': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': 5.000152590214416e-05, 'addresstype': 'tourism', 'name': 'Surmuche Hotel', 'display_name': 'Surmuche Hotel, NH28, Chetchet, Bigu-01, Lamabagar, Bigu, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'tourism': 'Surmuche Hotel', 'road': 'NH28', 'hamlet': 'Chetchet', 'city_district': 'Bigu-01', 'village': 'Lamabagar', 'municipality': 'Bigu', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8878072', '27.8879072', '86.2582597', '86.2583597']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 4)
# Location Info {'place_id': 223783293, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5223183040, 'lat': '27.9009832', 'lon': '86.2752002', 'class': 'place', 'type': 'isolated_dwelling', 'place_rank': 22, 'importance': 0.10671666819256884, 'addresstype': 'isolated_dwelling', 'name': 'Kyalche', 'display_name': 'Kyalche, Gaurishankar-09, Gaurishankar, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'isolated_dwelling': 'Kyalche', 'city_district': 'Gaurishankar-09', 'municipality': 'Gaurishankar', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9009332', '27.9010332', '86.2751502', '86.2752502']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 5)
# Location Info {'place_id': 223259019, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5222951778, 'lat': '27.9034258', 'lon': '86.288103', 'class': 'place', 'type': 'isolated_dwelling', 'place_rank': 22, 'importance': 0.10671666819256884, 'addresstype': 'isolated_dwelling', 'name': 'Dongang', 'display_name': 'Dongang, Gaurishankar-09, Gaurishankar, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'isolated_dwelling': 'Dongang', 'city_district': 'Gaurishankar-09', 'municipality': 'Gaurishankar', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9033758', '27.9034758', '86.2880530', '86.2881530']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 6)
# Location Info {'place_id': 223259019, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5222951778, 'lat': '27.9034258', 'lon': '86.288103', 'class': 'place', 'type': 'isolated_dwelling', 'place_rank': 22, 'importance': 0.10671666819256884, 'addresstype': 'isolated_dwelling', 'name': 'Dongang', 'display_name': 'Dongang, Gaurishankar-09, Gaurishankar, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'isolated_dwelling': 'Dongang', 'city_district': 'Gaurishankar-09', 'municipality': 'Gaurishankar', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9033758', '27.9034758', '86.2880530', '86.2881530']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 7)
# Location Info {'place_id': 222877987, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 11342720769, 'lat': '27.9034379', 'lon': '86.3265257', 'class': 'amenity', 'type': 'shelter', 'place_rank': 30, 'importance': 5.000152590214416e-05, 'addresstype': 'amenity', 'name': 'Lodge', 'display_name': 'Lodge, Thangdinam, Gaurishankar-09, Gaurishankar, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'amenity': 'Lodge', 'isolated_dwelling': 'Thangdinam', 'city_district': 'Gaurishankar-09', 'municipality': 'Gaurishankar', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9033879', '27.9034879', '86.3264757', '86.3265757']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 8)
# Location Info {'place_id': 224015883, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5223155349, 'lat': '27.9031544', 'lon': '86.3420865', 'class': 'amenity', 'type': 'place_of_worship', 'place_rank': 30, 'importance': 5.000152590214416e-05, 'addresstype': 'amenity', 'name': 'Sumda Mahades Hindu shrine', 'display_name': 'Sumda Mahades Hindu shrine, Gaurishankar-09, Gaurishankar, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'amenity': 'Sumda Mahades Hindu shrine', 'city_district': 'Gaurishankar-09', 'municipality': 'Gaurishankar', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9031044', '27.9032044', '86.3420365', '86.3421365']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 9)
# Location Info {'place_id': 223033154, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5223155117, 'lat': '27.9070726', 'lon': '86.3634476', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.1333833348592355, 'addresstype': 'hamlet', 'name': 'Ramding', 'display_name': 'Ramding, Gaurishankar-09, Gaurishankar, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Ramding', 'city_district': 'Gaurishankar-09', 'municipality': 'Gaurishankar', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8870726', '27.9270726', '86.3434476', '86.3834476']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 10)
# Location Info {'place_id': 222525921, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5223155049, 'lat': '27.9049642', 'lon': '86.3682367', 'class': 'amenity', 'type': 'school', 'place_rank': 30, 'importance': 5.000152590214416e-05, 'addresstype': 'amenity', 'name': 'रोल्वालिङ साङ्ग क्ष्योलिङ गुम्बा', 'display_name': 'रोल्वालिङ साङ्ग क्ष्योलिङ गुम्बा, Chhimu, Gaurishankar-09, Gaurishankar, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'amenity': 'रोल्वालिङ साङ्ग क्ष्योलिङ गुम्बा', 'hamlet': 'Chhimu', 'city_district': 'Gaurishankar-09', 'municipality': 'Gaurishankar', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9049142', '27.9050142', '86.3681867', '86.3682867']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 11)
# Location Info {'place_id': 225785582, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5223229941, 'lat': '27.9050483', 'lon': '86.3759091', 'class': 'historic', 'type': 'monastery', 'place_rank': 30, 'importance': 5.000152590214416e-05, 'addresstype': 'historic', 'name': 'historic Beding Gompa, Guru Rinpche cave', 'display_name': 'historic Beding Gompa, Guru Rinpche cave, Beding, Gaurishankar-09, Gaurishankar, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'historic': 'historic Beding Gompa, Guru Rinpche cave', 'hamlet': 'Beding', 'city_district': 'Gaurishankar-09', 'municipality': 'Gaurishankar', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9049983', '27.9050983', '86.3758591', '86.3759591']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 12)
# Location Info {'place_id': 224299861, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 3491013193, 'lat': '27.9028109', 'lon': '86.3755363', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.1333833348592355, 'addresstype': 'hamlet', 'name': 'Beding', 'display_name': 'Beding, Gaurishankar-09, Gaurishankar, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Beding', 'city_district': 'Gaurishankar-09', 'municipality': 'Gaurishankar', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8828109', '27.9228109', '86.3555363', '86.3955363']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 13)
# Location Info {'place_id': 224048115, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6743843, 'lat': '27.886434899999998', 'lon': '86.39908923317614', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.16005000152590218, 'addresstype': 'city_district', 'name': 'Gaurishankar-09', 'display_name': 'Gaurishankar-09, Gaurishankar, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'city_district': 'Gaurishankar-09', 'municipality': 'Gaurishankar', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8054351', '27.9673510', '86.2178718', '86.5547505']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 14)
# Location Info {'place_id': 224048115, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6743843, 'lat': '27.886434899999998', 'lon': '86.39908923317614', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.16005000152590218, 'addresstype': 'city_district', 'name': 'Gaurishankar-09', 'display_name': 'Gaurishankar-09, Gaurishankar, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'city_district': 'Gaurishankar-09', 'municipality': 'Gaurishankar', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8054351', '27.9673510', '86.2178718', '86.5547505']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 15)
# Location Info {'place_id': 224618610, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 8015923985, 'lat': '27.8812452', 'lon': '86.4260522', 'class': 'tourism', 'type': 'alpine_hut', 'place_rank': 30, 'importance': 5.000152590214416e-05, 'addresstype': 'tourism', 'name': 'Josef Phurba Lodge', 'display_name': 'Josef Phurba Lodge, Na, Gaurishankar-09, Gaurishankar, दोलखा, बागमती प्रदेश, 45500, नेपाल', 'address': {'tourism': 'Josef Phurba Lodge', 'hamlet': 'Na', 'city_district': 'Gaurishankar-09', 'municipality': 'Gaurishankar', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'postcode': '45500', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8811952', '27.8812952', '86.4260022', '86.4261022']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 16)
# Location Info {'place_id': 224048190, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 3491026788, 'lat': '27.8814863', 'lon': '86.42678', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.1333833348592355, 'addresstype': 'hamlet', 'name': 'Na', 'display_name': 'Na, Gaurishankar-09, Gaurishankar, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Na', 'city_district': 'Gaurishankar-09', 'municipality': 'Gaurishankar', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8614863', '27.9014863', '86.4067800', '86.4467800']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 17)
# Location Info {'place_id': 224048190, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 3491026788, 'lat': '27.8814863', 'lon': '86.42678', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.1333833348592355, 'addresstype': 'hamlet', 'name': 'Na', 'display_name': 'Na, Gaurishankar-09, Gaurishankar, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Na', 'city_district': 'Gaurishankar-09', 'municipality': 'Gaurishankar', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8614863', '27.9014863', '86.4067800', '86.4467800']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 18)
# Location Info {'place_id': 224048115, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6743843, 'lat': '27.886434899999998', 'lon': '86.39908923317614', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.16005000152590218, 'addresstype': 'city_district', 'name': 'Gaurishankar-09', 'display_name': 'Gaurishankar-09, Gaurishankar, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'city_district': 'Gaurishankar-09', 'municipality': 'Gaurishankar', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8054351', '27.9673510', '86.2178718', '86.5547505']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 19)
# Location Info {'place_id': 224048115, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6743843, 'lat': '27.886434899999998', 'lon': '86.39908923317614', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.16005000152590218, 'addresstype': 'city_district', 'name': 'Gaurishankar-09', 'display_name': 'Gaurishankar-09, Gaurishankar, दोलखा, बागमती प्रदेश, नेपाल', 'address': {'city_district': 'Gaurishankar-09', 'municipality': 'Gaurishankar', 'county': 'दोलखा', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8054351', '27.9673510', '86.2178718', '86.5547505']}
# Processing: Feature-Barhabise to TshoRolpa (Line 6, Point 20)
# ...
# Processing: Feature-Kapthang to Larcha (Line 1, Point 49)
# Location Info {'place_id': 224016340, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 8702386489, 'lat': '27.9007198', 'lon': '85.9340732', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.14671666819256882, 'addresstype': 'village', 'name': 'Silinkatti', 'display_name': 'Silinkatti, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'village': 'Silinkatti', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8807198', '27.9207198', '85.9140732', '85.9540732']}
# Processing: Feature-Kapthang to Larcha (Line 1, Point 50)
# Location Info {'place_id': 224016340, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 8702386489, 'lat': '27.9007198', 'lon': '85.9340732', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.14671666819256882, 'addresstype': 'village', 'name': 'Silinkatti', 'display_name': 'Silinkatti, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'village': 'Silinkatti', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8807198', '27.9207198', '85.9140732', '85.9540732']}
# Processing: Feature-Kapthang to Larcha (Line 1, Point 51)
# Location Info {'place_id': 224016340, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 8702386489, 'lat': '27.9007198', 'lon': '85.9340732', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.14671666819256882, 'addresstype': 'village', 'name': 'Silinkatti', 'display_name': 'Silinkatti, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'village': 'Silinkatti', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8807198', '27.9207198', '85.9140732', '85.9540732']}
# Processing: Feature-Kapthang to Larcha (Line 1, Point 52)
# Location Info {'place_id': 224016340, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 8702386489, 'lat': '27.9007198', 'lon': '85.9340732', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.14671666819256882, 'addresstype': 'village', 'name': 'Silinkatti', 'display_name': 'Silinkatti, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'village': 'Silinkatti', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.8807198', '27.9207198', '85.9140732', '85.9540732']}
# Processing: Feature-Kapthang to Larcha (Line 1, Point 53)
# Location Info {'place_id': 223259698, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 8703133593, 'lat': '27.9258527', 'lon': '85.9588764', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.1333833348592355, 'addresstype': 'hamlet', 'name': 'Namtan', 'display_name': 'Namtan, Bhotekoshi-04, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Namtan', 'city_district': 'Bhotekoshi-04', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9058527', '27.9458527', '85.9388764', '85.9788764']}
# Processing: Feature-Kapthang to Larcha (Line 1, Point 54)
# Location Info {'place_id': 223259698, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 8703133593, 'lat': '27.9258527', 'lon': '85.9588764', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.1333833348592355, 'addresstype': 'hamlet', 'name': 'Namtan', 'display_name': 'Namtan, Bhotekoshi-04, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Namtan', 'city_district': 'Bhotekoshi-04', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9058527', '27.9458527', '85.9388764', '85.9788764']}
# Processing: Feature-Kapthang to Larcha (Line 1, Point 55)
# Location Info {'place_id': 223259698, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 8703133593, 'lat': '27.9258527', 'lon': '85.9588764', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.1333833348592355, 'addresstype': 'hamlet', 'name': 'Namtan', 'display_name': 'Namtan, Bhotekoshi-04, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Namtan', 'city_district': 'Bhotekoshi-04', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9058527', '27.9458527', '85.9388764', '85.9788764']}
# Processing: Feature-Kapthang to Larcha (Line 1, Point 56)
# Location Info {'place_id': 223259698, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 8703133593, 'lat': '27.9258527', 'lon': '85.9588764', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.1333833348592355, 'addresstype': 'hamlet', 'name': 'Namtan', 'display_name': 'Namtan, Bhotekoshi-04, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Namtan', 'city_district': 'Bhotekoshi-04', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9058527', '27.9458527', '85.9388764', '85.9788764']}
# Processing: Feature-Kapthang to Larcha (Line 1, Point 57)
# Location Info {'place_id': 223715532, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 341660801, 'lat': '27.9243005', 'lon': '85.9514255', 'class': 'highway', 'type': 'unclassified', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': '', 'display_name': 'Namtan, Bhotekoshi-04, तातोपानी, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Namtan', 'city_district': 'Bhotekoshi-04', 'village': 'तातोपानी', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9237070', '27.9383558', '85.9409373', '85.9610849']}
# Processing: Feature-Kapthang to Larcha (Line 1, Point 58)
# Location Info {'place_id': 223715532, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 341660801, 'lat': '27.9243005', 'lon': '85.9514255', 'class': 'highway', 'type': 'unclassified', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': '', 'display_name': 'Namtan, Bhotekoshi-04, तातोपानी, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Namtan', 'city_district': 'Bhotekoshi-04', 'village': 'तातोपानी', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9237070', '27.9383558', '85.9409373', '85.9610849']}
# Processing: Feature-Kapthang to Larcha (Line 1, Point 59)
# Location Info {'place_id': 223715532, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 341660801, 'lat': '27.92420163030755', 'lon': '85.94930861148961', 'class': 'highway', 'type': 'unclassified', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': '', 'display_name': 'Namtan, Bhotekoshi-04, तातोपानी, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Namtan', 'city_district': 'Bhotekoshi-04', 'village': 'तातोपानी', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9237070', '27.9383558', '85.9409373', '85.9610849']}
# Processing: Feature-Kapthang to Larcha (Line 1, Point 60)
# Location Info {'place_id': 223715532, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 341660801, 'lat': '27.924329114941354', 'lon': '85.94718583885509', 'class': 'highway', 'type': 'unclassified', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': '', 'display_name': 'Namtan, Bhotekoshi-04, तातोपानी, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Namtan', 'city_district': 'Bhotekoshi-04', 'village': 'तातोपानी', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9237070', '27.9383558', '85.9409373', '85.9610849']}
# Processing: Feature-Kapthang to Larcha (Line 1, Point 61)
# Location Info {'place_id': 223715532, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 341660801, 'lat': '27.924143137533793', 'lon': '85.94459716641396', 'class': 'highway', 'type': 'unclassified', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': '', 'display_name': 'Namtan, Bhotekoshi-04, तातोपानी, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Namtan', 'city_district': 'Bhotekoshi-04', 'village': 'तातोपानी', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9237070', '27.9383558', '85.9409373', '85.9610849']}
# Processing: Feature-Kapthang to Larcha (Line 1, Point 62)
# Location Info {'place_id': 223715532, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 341660801, 'lat': '27.92523690952687', 'lon': '85.9437987525152', 'class': 'highway', 'type': 'unclassified', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': '', 'display_name': 'Namtan, Bhotekoshi-04, तातोपानी, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Namtan', 'city_district': 'Bhotekoshi-04', 'village': 'तातोपानी', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9237070', '27.9383558', '85.9409373', '85.9610849']}
# Processing: Feature-Kapthang to Larcha (Line 1, Point 63)
# Location Info {'place_id': 223715532, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 341660801, 'lat': '27.927372475752232', 'lon': '85.9419596383925', 'class': 'highway', 'type': 'unclassified', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': '', 'display_name': 'Namtan, Bhotekoshi-04, तातोपानी, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Namtan', 'city_district': 'Bhotekoshi-04', 'village': 'तातोपानी', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9237070', '27.9383558', '85.9409373', '85.9610849']}
# Processing: Feature-Kapthang to Larcha (Line 1, Point 64)
# Location Info {'place_id': 223715532, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 341660801, 'lat': '27.9273821', 'lon': '85.9419482', 'class': 'highway', 'type': 'unclassified', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': '', 'display_name': 'Namtan, Bhotekoshi-04, तातोपानी, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Namtan', 'city_district': 'Bhotekoshi-04', 'village': 'तातोपानी', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9237070', '27.9383558', '85.9409373', '85.9610849']}
# Processing: Feature-Kapthang to Larcha (Line 1, Point 65)
# Location Info {'place_id': 223715532, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 341660801, 'lat': '27.9279973', 'lon': '85.9415415', 'class': 'highway', 'type': 'unclassified', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': '', 'display_name': 'Namtan, Bhotekoshi-04, तातोपानी, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'hamlet': 'Namtan', 'city_district': 'Bhotekoshi-04', 'village': 'तातोपानी', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9237070', '27.9383558', '85.9409373', '85.9610849']}
# Processing: Feature-Kapthang to Larcha (Line 1, Point 66)
# Location Info {'place_id': 223784192, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 922814825, 'lat': '27.93261678950501', 'lon': '85.93784842127405', 'class': 'highway', 'type': 'trunk', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': 'NH34', 'display_name': 'NH34, Larcha, Bhotekoshi-03, Khukundol, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'road': 'NH34', 'hamlet': 'Larcha', 'city_district': 'Bhotekoshi-03', 'village': 'Khukundol', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9322745', '27.9350367', '85.9369886', '85.9395808']}
# Processing: Feature-Kapthang to Larcha (Line 1, Point 67)
# Location Info {'place_id': 222879113, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 938421589, 'lat': '27.93201293452371', 'lon': '85.93672924242081', 'class': 'highway', 'type': 'trunk', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': 'NH34', 'display_name': 'NH34, Larcha, Bhotekoshi-03, Khukundol, Bhotekoshi, सिन्धुपाल्चोक, बागमती प्रदेश, नेपाल', 'address': {'road': 'NH34', 'hamlet': 'Larcha', 'city_district': 'Bhotekoshi-03', 'village': 'Khukundol', 'municipality': 'Bhotekoshi', 'county': 'सिन्धुपाल्चोक', 'state': 'बागमती प्रदेश', 'ISO3166-2-lvl4': 'NP-P3', 'country': 'नेपाल', 'country_code': 'np'}, 'boundingbox': ['27.9318836', '27.9322745', '85.9367056', '85.9369886']}
# Results saved to dataset/processed/location_info.json

# %%
def json_to_csv(json_file_path, csv_file_path):
    # Read JSON data
    with open(json_file_path, "r", encoding="utf-8") as json_file:
        data = json.load(json_file)

    # If data is not a list (single record), convert it to a list
    if not isinstance(data, list):
        data = [data]

    # Extract all possible keys from the nested structure
    csv_headers = ["name", "type", "longitude", "latitude", "source_file"]
    location_info_headers = set()
    address_headers = set()

    for item in data:
        if "location_info" in item:
            for key in item["location_info"].keys():
                if key != "address":  # Handle address separately
                    location_info_headers.add(key)

            # Extract address keys if address exists
            if "address" in item["location_info"]:
                for addr_key in item["location_info"]["address"].keys():
                    address_headers.add(addr_key)

    # Convert sets to sorted lists for consistent ordering
    location_info_headers = sorted(list(location_info_headers))
    address_headers = sorted(list(address_headers))

    # Create full header list with prefixes for clarity
    full_headers = csv_headers.copy()
    for header in location_info_headers:
        if header != "address":  # Skip address as we'll handle it separately
            full_headers.append(f"location_{header}")

    for header in address_headers:
        full_headers.append(f"address_{header}")

    # Write data to CSV
    with open(csv_file_path, "w", newline="", encoding="utf-8") as csv_file:
        writer = csv.DictWriter(csv_file, fieldnames=full_headers)
        writer.writeheader()

        for item in data:
            row = {}

            # Add base fields
            for header in csv_headers:
                row[header] = item.get(header, "")

            # Add location_info fields
            if "location_info" in item:
                for header in location_info_headers:
                    if header != "address":  # Skip address
                        row[f"location_{header}"] = item["location_info"].get(
                            header, ""
                        )

                # Add address fields if available
                if "address" in item["location_info"]:
                    for addr_header in address_headers:
                        row[f"address_{addr_header}"] = item["location_info"][
                            "address"
                        ].get(addr_header, "")

            writer.writerow(row)

# %%
input_json = "dataset/processed/location_info.json"  # Change to your input file
output_csv = (
    "dataset/processed/location_results.csv"  # Change to your desired output file
)

json_to_csv(input_json, output_csv)
print(f"Conversion complete. CSV file saved as {output_csv}")
# Out:
# Conversion complete. CSV file saved as dataset/processed/location_results.csv

# %%
df = pd.read_csv("./dataset/final/final_elevation_filtered.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381 entries, 0 to 380
# Data columns (total 20 columns):
#  #   Column                                                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                                                    --------------  -----
#  0   latitude                                                                                                                                                  381 non-null    float64
#  1   longitude                                                                                                                                                 381 non-null    float64
#  2   location_name                                                                                                                                             381 non-null    object
#  3   location_addresstype                                                                                                                                      381 non-null    object
#  4   location_boundingbox                                                                                                                                      381 non-null    object
#  5   location_class                                                                                                                                            381 non-null    object
#  6   location_display_name                                                                                                                                     381 non-null    object
#  7   location_importance                                                                                                                                       381 non-null    float64
#  8   location_lat                                                                                                                                              381 non-null    float64
#  9   location_lon                                                                                                                                              381 non-null    float64
#  10  location_osm_id                                                                                                                                           381 non-null    int64
#  11  location_place_id                                                                                                                                         381 non-null    int64
#  12  location_place_rank                                                                                                                                       381 non-null    int64
#  13  address_city_district                                                                                                                                     381 non-null    object
#  14  address_county                                                                                                                                            381 non-null    object
#  15  address_municipality                                                                                                                                      381 non-null    object
#  16  address_road                                                                                                                                              381 non-null    object
#  17  address_village                                                                                                                                           381 non-null    object
#  18  address_hamlet                                                                                                                                            381 non-null    object
#  19  altitude                                                                                                                                                  381 non-null    int64
# dtypes: float64(5), int64(4), object(11)
# memory usage: 59.7+ KB

# %%
df.describe()
# Out:
#        latitude           longitude          location_importance    \
# count         381.000000         381.000000             381.000000
# mean           27.817914          86.106217               0.080118
# std             0.118762           0.240670               0.053237
# min            27.574200          85.751900               0.000040
# 25%            27.751100          85.873100               0.053383
# 50%            27.818950          86.155700               0.053383
# 75%            27.887850          86.324100               0.146717
# max            28.133700          86.551800               0.160050
#
#        location_lat       location_lon       location_osm_id   \
# count         381.000000         381.000000      3.810000e+02
# mean           27.817673          86.102098      1.616376e+09
# std             0.117080           0.237855      2.632026e+09
# min            27.574119          85.744471      6.720524e+06
# 25%            27.742438          85.870577      3.168326e+08
# 50%            27.816637          86.156207      3.412837e+08
# 75%            27.890171          86.312076      1.309207e+09
# max            28.134569          86.552753      1.213794e+10
#
#        location_place_id   location_place_rank      altitude
# count        3.810000e+02            381.000000   381.000000
# mean         2.243426e+08             23.994751  2456.863517
# std          1.087259e+06              3.992753  1174.249403
# min          2.225150e+08             18.000000   684.000000
# 25%          2.237803e+08             19.000000  1548.000000
# 50%          2.241310e+08             26.000000  2260.000000
# 75%          2.248666e+08             26.000000  3424.000000
# max          2.290404e+08             30.000000  5726.000000
